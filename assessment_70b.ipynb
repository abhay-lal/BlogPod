# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
df=pd.read_csv('assessment_70b.csv')

# %%
df
# Out:
#               id                                     assessment_70b
# 0             id                                     assessment_70b
# 1             id                                     assessment_70b
# 2    TRdL6ZzWBS0  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 3    BCdV6BMMpOo  3,4,6,2,3,1\n\nSuggestions: This blog post is ...
# 4    Kedt2or9xlo  8,7,8,7,7,6\n\nSuggestions:\n\n* **Clarity (8)...
# ..           ...                                                ...
# 97   U_AREIyd0Fc  7,8,8,7,6,5\n\nSuggestions:\n\n* **Clarity (7)...
# 98   Whtt2H5_isM  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 99   i6rnzk8VU24  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 100  vNOTDn3D_RI  5,6,7,4,5,3\n\nSuggestions:\n\n* **Clarity (5)...
# 101  Z_LhPMhkEdw  4,3,6,2,5,1\n\nSuggestions:This blog post suff...
#
# [102 rows x 2 columns]

# %%
df = df[df['id'] != 'id']

# %%
df[['Scores', 'Suggestions']] = df['assessment_70b'].str.split('\n\nSuggestions:', expand=True)
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2873549970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Scores', 'Suggestions']] = df['assessment_70b'].str.split('\n\nSuggestions:', expand=True)
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2873549970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Scores', 'Suggestions']] = df['assessment_70b'].str.split('\n\nSuggestions:', expand=True)

# %%
scores_split = df['Scores'].str.split(',', expand=True)

scores_split = scores_split.reindex(columns=range(6))

scores_split.columns = ['Clarity', 'Grammar and Syntax', 'Tone Appropriateness', 
                        'Sentence Structure and Flow', 'Engagement', 'Conciseness']

df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness', 
    'Sentence Structure and Flow', 'Engagement', 'Conciseness']] = scores_split
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/2460940657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',

# %%
df
# Out:
#               id                                     assessment_70b  \
# 2    TRdL6ZzWBS0  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 3    BCdV6BMMpOo  3,4,6,2,3,1\n\nSuggestions: This blog post is ...
# 4    Kedt2or9xlo  8,7,8,7,7,6\n\nSuggestions:\n\n* **Clarity (8)...
# 5    M95m2EFb7IQ  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 6    R5rNoV1Qy_Q  7,8,8,7,7,6\n\nSuggestions:\n\n* **Clarity (7)...
# ..           ...                                                ...
# 97   U_AREIyd0Fc  7,8,8,7,6,5\n\nSuggestions:\n\n* **Clarity (7)...
# 98   Whtt2H5_isM  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 99   i6rnzk8VU24  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 100  vNOTDn3D_RI  5,6,7,4,5,3\n\nSuggestions:\n\n* **Clarity (5)...
# 101  Z_LhPMhkEdw  4,3,6,2,5,1\n\nSuggestions:This blog post suff...
#
#           Scores                                        Suggestions Clarity  \
# 2    7,8,8,7,6,6  \n\n* **Clarity (7):** While the blog generall...       7
# 3    3,4,6,2,3,1   This blog post is severely flawed and require...       3
# 4    8,7,8,7,7,6  \n\n* **Clarity (8):** While generally clear, ...       8
# 5    7,8,9,7,6,6  \n\n* **Clarity (7):** While the blog is gener...       7
# 6    7,8,8,7,7,6  \n\n* **Clarity (7):** While the central theme...       7
# ..           ...                                                ...     ...
# 97   7,8,8,7,6,5  \n\n* **Clarity (7):** While the blog is gener...       7
# 98   7,8,9,7,6,6  \n\n* **Clarity (7):** While the overall topic...       7
# 99   7,8,8,7,6,6  \n\n* **Clarity (7):** While the overall topic...       7
# 100  5,6,7,4,5,3  \n\n* **Clarity (5):** While the blog post gen...       5
# 101  4,3,6,2,5,1  This blog post suffers from severe repetition ...       4
#
#     Grammar and Syntax Tone Appropriateness Sentence Structure and Flow  \
# 2                    8                    8                           7
# 3                    4                    6                           2
# 4                    7                    8                           7
# 5                    8                    9                           7
# 6                    8                    8                           7
# ..                 ...                  ...                         ...
# 97                   8                    8                           7
# 98                   8                    9                           7
# 99                   8                    8                           7
# 100                  6                    7                           4
# 101                  3                    6                           2
#
#     Engagement Conciseness
# 2            6           6
# 3            3           1
# 4            7           6
# 5            6           6
# 6            7           6
# ..         ...         ...
# 97           6           5
# 98           6           6
# 99           6           6
# 100          5           3
# 101          5           1
#
# [100 rows x 10 columns]

# %%
df[['Clarity', 'Grammar and Syntax', 'Tone Appropriateness', 
    'Sentence Structure and Flow', 'Engagement', 'Conciseness']].apply(pd.to_numeric, errors='coerce').hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'Clarity'}>,
#         <Axes: title={'center': 'Grammar and Syntax'}>],
#        [<Axes: title={'center': 'Tone Appropriateness'}>,
#         <Axes: title={'center': 'Sentence Structure and Flow'}>],
#        [<Axes: title={'center': 'Engagement'}>,
#         <Axes: title={'center': 'Conciseness'}>]], dtype=object)

# %%
attributes = ["Clarity", "Grammar and Syntax", "Tone Appropriateness", 
              "Sentence Structure and Flow", "Engagement", "Conciseness"]

def extract_attribute_comments_regex(suggestions_text, attribute, attributes_list):
    pattern = r'(\* \*\*' + re.escape(attribute) + r' \(\d+\):.*?)(?=\n\* \*\*(' + '|'.join([re.escape(attr) for attr in attributes_list]) + r') \(\d+\)|$)'
    
    match = re.search(pattern, suggestions_text, re.DOTALL)
    
    return match.group(1).strip() if match else None

for attribute in attributes:
    df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/418202715.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df["Suggestions"].apply(lambda x: extract_attribute_comments_regex(str(x), attribute, attributes))

# %%
df
# Out:
#               id                                     assessment_70b  \
# 2    TRdL6ZzWBS0  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 3    BCdV6BMMpOo  3,4,6,2,3,1\n\nSuggestions: This blog post is ...
# 4    Kedt2or9xlo  8,7,8,7,7,6\n\nSuggestions:\n\n* **Clarity (8)...
# 5    M95m2EFb7IQ  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 6    R5rNoV1Qy_Q  7,8,8,7,7,6\n\nSuggestions:\n\n* **Clarity (7)...
# ..           ...                                                ...
# 97   U_AREIyd0Fc  7,8,8,7,6,5\n\nSuggestions:\n\n* **Clarity (7)...
# 98   Whtt2H5_isM  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 99   i6rnzk8VU24  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 100  vNOTDn3D_RI  5,6,7,4,5,3\n\nSuggestions:\n\n* **Clarity (5)...
# 101  Z_LhPMhkEdw  4,3,6,2,5,1\n\nSuggestions:This blog post suff...
#
#           Scores                                        Suggestions Clarity  \
# 2    7,8,8,7,6,6  \n\n* **Clarity (7):** While the blog generall...       7
# 3    3,4,6,2,3,1   This blog post is severely flawed and require...       3
# 4    8,7,8,7,7,6  \n\n* **Clarity (8):** While generally clear, ...       8
# 5    7,8,9,7,6,6  \n\n* **Clarity (7):** While the blog is gener...       7
# 6    7,8,8,7,7,6  \n\n* **Clarity (7):** While the central theme...       7
# ..           ...                                                ...     ...
# 97   7,8,8,7,6,5  \n\n* **Clarity (7):** While the blog is gener...       7
# 98   7,8,9,7,6,6  \n\n* **Clarity (7):** While the overall topic...       7
# 99   7,8,8,7,6,6  \n\n* **Clarity (7):** While the overall topic...       7
# 100  5,6,7,4,5,3  \n\n* **Clarity (5):** While the blog post gen...       5
# 101  4,3,6,2,5,1  This blog post suffers from severe repetition ...       4
#
#     Grammar and Syntax Tone Appropriateness Sentence Structure and Flow  \
# 2                    8                    8                           7
# 3                    4                    6                           2
# 4                    7                    8                           7
# 5                    8                    9                           7
# 6                    8                    8                           7
# ..                 ...                  ...                         ...
# 97                   8                    8                           7
# 98                   8                    9                           7
# 99                   8                    8                           7
# 100                  6                    7                           4
# 101                  3                    6                           2
#
#     Engagement Conciseness                                   Clarity Comments  \
# 2            6           6  * **Clarity (7):** While the blog generally ex...
# 3            3           1  * **Clarity (3):**  The blog post is incredibl...
# 4            7           6  * **Clarity (8):** While generally clear, some...
# 5            6           6  * **Clarity (7):** While the blog is generally...
# 6            7           6  * **Clarity (7):** While the central theme is ...
# ..         ...         ...                                                ...
# 97           6           5  * **Clarity (7):** While the blog is generally...
# 98           6           6  * **Clarity (7):** While the overall topic is ...
# 99           6           6  * **Clarity (7):** While the overall topic is ...
# 100          5           3  * **Clarity (5):** While the blog post general...
# 101          5           1  * **Clarity (4):**  The central message is mud...
#
#                            Grammar and Syntax Comments  \
# 2    * **Grammar and Syntax (8):** The grammar is l...
# 3    * **Grammar and Syntax (4):** While there are ...
# 4    * **Grammar and Syntax (7):** There are a few ...
# 5    * **Grammar and Syntax (8):** The grammar is l...
# 6    * **Grammar and Syntax (8):** There are a few ...
# ..                                                 ...
# 97   * **Grammar and Syntax (8):** The grammar is m...
# 98   * **Grammar and Syntax (8):** The grammar is m...
# 99   * **Grammar and Syntax (8):** The grammar is m...
# 100  * **Grammar and Syntax (6):**  There are sever...
# 101  * **Grammar and Syntax (3):** While there are ...
#
#                          Tone Appropriateness Comments  \
# 2    * **Tone Appropriateness (8):** The tone is ge...
# 3    * **Tone Appropriateness (6):** The tone is ge...
# 4    * **Tone Appropriateness (8):** The tone is ge...
# 5    * **Tone Appropriateness (9):** The tone is co...
# 6    * **Tone Appropriateness (8):** The tone is ge...
# ..                                                 ...
# 97   * **Tone Appropriateness (8):** The tone is ge...
# 98   * **Tone Appropriateness (9):** The tone is ge...
# 99   * **Tone Appropriateness (8):** The tone is ge...
# 100  * **Tone Appropriateness (7):** The tone is ge...
# 101  * **Tone Appropriateness (6):** The tone is ge...
#
#                   Sentence Structure and Flow Comments  \
# 2    * **Sentence Structure and Flow (7):** The blo...
# 3    * **Sentence Structure and Flow (2):** The sen...
# 4    * **Sentence Structure and Flow (7):** The blo...
# 5    * **Sentence Structure and Flow (7):**  The bl...
# 6    * **Sentence Structure and Flow (7):** The flo...
# ..                                                 ...
# 97   * **Sentence Structure and Flow (7):** The blo...
# 98   * **Sentence Structure and Flow (7):** The blo...
# 99   * **Sentence Structure and Flow (7):** The flo...
# 100  * **Sentence Structure and Flow (4):** This is...
# 101  * **Sentence Structure and Flow (2):** The blo...
#
#                                    Engagement Comments  \
# 2    * **Engagement (6):** While the topic itself i...
# 3    * **Engagement (3):** The blog post fails to e...
# 4    * **Engagement (7):**  The blog is informative...
# 5    * **Engagement (6):** While the subject matter...
# 6    * **Engagement (7):** The blog engages the rea...
# ..                                                 ...
# 97   * **Engagement (6):** The blog lacks engaging ...
# 98   * **Engagement (6):** The blog is informative ...
# 99   * **Engagement (6):** The blog post lacks comp...
# 100  * **Engagement (5):** The blog lacks engaging ...
# 101  * **Engagement (5):** The repetitive nature of...
#
#                                   Conciseness Comments
# 2    * **Conciseness (6):** The blog is somewhat ve...
# 3    * **Conciseness (1):** This is the most signif...
# 4    * **Conciseness (6):** The blog could be more ...
# 5    * **Conciseness (6):**  The blog is somewhat v...
# 6    * **Conciseness (6):** The blog is significant...
# ..                                                 ...
# 97   * **Conciseness (5):**  The blog is significan...
# 98   * **Conciseness (6):**  The blog could be more...
# 99   * **Conciseness (6):**  Several sections could...
# 100  * **Conciseness (3):** This is another severel...
# 101  * **Conciseness (1):** This is the blog's bigg...
#
# [100 rows x 16 columns]

# %%
def clean_comments(comment, attribute):
    if pd.isna(comment):
        return comment
    return re.sub(r'\*\*' + re.escape(attribute) + r' \(\d+\):\*\* ', '', comment)

for attribute in attributes:
    df[f"{attribute} Comments"] = df[f"{attribute} Comments"].apply(lambda x: clean_comments(x, attribute))

df.head()
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/3072347428.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{attribute} Comments"] = df[f"{attribute} Comments"].apply(lambda x: clean_comments(x, attribute))
#             id                                     assessment_70b  \
# 2  TRdL6ZzWBS0  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 3  BCdV6BMMpOo  3,4,6,2,3,1\n\nSuggestions: This blog post is ...
# 4  Kedt2or9xlo  8,7,8,7,7,6\n\nSuggestions:\n\n* **Clarity (8)...
# 5  M95m2EFb7IQ  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 6  R5rNoV1Qy_Q  7,8,8,7,7,6\n\nSuggestions:\n\n* **Clarity (7)...
#
#         Scores                                        Suggestions Clarity  \
# 2  7,8,8,7,6,6  \n\n* **Clarity (7):** While the blog generall...       7
# 3  3,4,6,2,3,1   This blog post is severely flawed and require...       3
# 4  8,7,8,7,7,6  \n\n* **Clarity (8):** While generally clear, ...       8
# 5  7,8,9,7,6,6  \n\n* **Clarity (7):** While the blog is gener...       7
# 6  7,8,8,7,7,6  \n\n* **Clarity (7):** While the central theme...       7
#
#   Grammar and Syntax Tone Appropriateness Sentence Structure and Flow  \
# 2                  8                    8                           7
# 3                  4                    6                           2
# 4                  7                    8                           7
# 5                  8                    9                           7
# 6                  8                    8                           7
#
#   Engagement Conciseness                                   Clarity Comments  \
# 2          6           6  * While the blog generally explains complex co...
# 3          3           1  *  The blog post is incredibly repetitive and ...
# 4          7           6  * While generally clear, some sections lack pr...
# 5          6           6  * While the blog is generally understandable, ...
# 6          7           6  * While the central theme is understandable, s...
#
#                          Grammar and Syntax Comments  \
# 2  * The grammar is largely correct, but there ar...
# 3  * While there are no egregious grammatical err...
# 4  * There are a few minor grammatical inconsiste...
# 5  * The grammar is largely correct, but there ar...
# 6  * There are a few minor grammatical issues and...
#
#                        Tone Appropriateness Comments  \
# 2  * The tone is generally appropriate for a gene...
# 3  * The tone is generally appropriate for a gene...
# 4  * The tone is generally appropriate for a gene...
# 5  * The tone is consistently informative and eng...
# 6  * The tone is generally appropriate for a gene...
#
#                 Sentence Structure and Flow Comments  \
# 2  * The blog suffers from a lack of smooth trans...
# 3  * The sentence structure is dreadful.  The lac...
# 4  * The blog suffers from some choppiness in pla...
# 5  *  The blog suffers from a somewhat repetitive...
# 6  * The flow is mostly smooth, but the blog suff...
#
#                                  Engagement Comments  \
# 2  * While the topic itself is inherently interes...
# 3  * The blog post fails to engage the reader. Th...
# 4  *  The blog is informative but could be more e...
# 5  * While the subject matter is inherently inter...
# 6  * The blog engages the reader to a degree, usi...
#
#                                 Conciseness Comments
# 2  * The blog is somewhat verbose. Many sentences...
# 3  * This is the most significant weakness. The b...
# 4  * The blog could be more concise.  Some sectio...
# 5  *  The blog is somewhat verbose.  Some points ...
# 6  * The blog is significantly too long and repet...

# %%
import matplotlib.pyplot as plt

# Convert the scores columns to numeric
df[attributes] = df[attributes].apply(pd.to_numeric, errors='coerce')

# Plot the scores based on the ids
df.set_index('id')[attributes].plot(figsize=(15, 10), marker='o')
plt.title('Scores based on IDs')
plt.xlabel('ID')
plt.ylabel('Scores')
plt.legend(title='Attributes')
plt.grid(True)
plt.show()
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_74941/3246758144.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[attributes] = df[attributes].apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#               id                                     assessment_70b  \
# 2    TRdL6ZzWBS0  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 3    BCdV6BMMpOo  3,4,6,2,3,1\n\nSuggestions: This blog post is ...
# 4    Kedt2or9xlo  8,7,8,7,7,6\n\nSuggestions:\n\n* **Clarity (8)...
# 5    M95m2EFb7IQ  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 6    R5rNoV1Qy_Q  7,8,8,7,7,6\n\nSuggestions:\n\n* **Clarity (7)...
# ..           ...                                                ...
# 97   U_AREIyd0Fc  7,8,8,7,6,5\n\nSuggestions:\n\n* **Clarity (7)...
# 98   Whtt2H5_isM  7,8,9,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 99   i6rnzk8VU24  7,8,8,7,6,6\n\nSuggestions:\n\n* **Clarity (7)...
# 100  vNOTDn3D_RI  5,6,7,4,5,3\n\nSuggestions:\n\n* **Clarity (5)...
# 101  Z_LhPMhkEdw  4,3,6,2,5,1\n\nSuggestions:This blog post suff...
#
#           Scores                                        Suggestions  Clarity  \
# 2    7,8,8,7,6,6  \n\n* **Clarity (7):** While the blog generall...        7
# 3    3,4,6,2,3,1   This blog post is severely flawed and require...        3
# 4    8,7,8,7,7,6  \n\n* **Clarity (8):** While generally clear, ...        8
# 5    7,8,9,7,6,6  \n\n* **Clarity (7):** While the blog is gener...        7
# 6    7,8,8,7,7,6  \n\n* **Clarity (7):** While the central theme...        7
# ..           ...                                                ...      ...
# 97   7,8,8,7,6,5  \n\n* **Clarity (7):** While the blog is gener...        7
# 98   7,8,9,7,6,6  \n\n* **Clarity (7):** While the overall topic...        7
# 99   7,8,8,7,6,6  \n\n* **Clarity (7):** While the overall topic...        7
# 100  5,6,7,4,5,3  \n\n* **Clarity (5):** While the blog post gen...        5
# 101  4,3,6,2,5,1  This blog post suffers from severe repetition ...        4
#
#      Grammar and Syntax  Tone Appropriateness  Sentence Structure and Flow  \
# 2                     8                     8                            7
# 3                     4                     6                            2
# 4                     7                     8                            7
# 5                     8                     9                            7
# 6                     8                     8                            7
# ..                  ...                   ...                          ...
# 97                    8                     8                            7
# 98                    8                     9                            7
# 99                    8                     8                            7
# 100                   6                     7                            4
# 101                   3                     6                            2
#
#      Engagement  Conciseness  \
# 2             6            6
# 3             3            1
# 4             7            6
# 5             6            6
# 6             7            6
# ..          ...          ...
# 97            6            5
# 98            6            6
# 99            6            6
# 100           5            3
# 101           5            1
#
#                                       Clarity Comments  \
# 2    * While the blog generally explains complex co...
# 3    *  The blog post is incredibly repetitive and ...
# 4    * While generally clear, some sections lack pr...
# 5    * While the blog is generally understandable, ...
# 6    * While the central theme is understandable, s...
# ..                                                 ...
# 97   * While the blog is generally understandable, ...
# 98   * While the overall topic is clear, some secti...
# 99   * While the overall topic is clear, certain se...
# 100  * While the blog post generally discusses Gary...
# 101  *  The central message is muddled by the exces...
#
#                            Grammar and Syntax Comments  \
# 2    * The grammar is largely correct, but there ar...
# 3    * While there are no egregious grammatical err...
# 4    * There are a few minor grammatical inconsiste...
# 5    * The grammar is largely correct, but there ar...
# 6    * There are a few minor grammatical issues and...
# ..                                                 ...
# 97   * The grammar is mostly correct, but there are...
# 98   * The grammar is mostly correct, but there are...
# 99   * The grammar is mostly correct, but there are...
# 100  *  There are several instances of repetitive p...
# 101  * While there are no glaring grammatical error...
#
#                          Tone Appropriateness Comments  \
# 2    * The tone is generally appropriate for a gene...
# 3    * The tone is generally appropriate for a gene...
# 4    * The tone is generally appropriate for a gene...
# 5    * The tone is consistently informative and eng...
# 6    * The tone is generally appropriate for a gene...
# ..                                                 ...
# 97   * The tone is generally appropriate for a gene...
# 98   * The tone is generally appropriate for a gene...
# 99   * The tone is generally appropriate for a gene...
# 100  * The tone is generally appropriate for a gene...
# 101  * The tone is generally appropriate for a gene...
#
#                   Sentence Structure and Flow Comments  \
# 2    * The blog suffers from a lack of smooth trans...
# 3    * The sentence structure is dreadful.  The lac...
# 4    * The blog suffers from some choppiness in pla...
# 5    *  The blog suffers from a somewhat repetitive...
# 6    * The flow is mostly smooth, but the blog suff...
# ..                                                 ...
# 97   * The blog suffers from a lack of transitional...
# 98   * The blog suffers from a somewhat repetitive ...
# 99   * The flow of ideas is generally logical, but ...
# 100  * This is the weakest area.  The blog suffers ...
# 101  * The blog post severely lacks flow.  The cons...
#
#                                    Engagement Comments  \
# 2    * While the topic itself is inherently interes...
# 3    * The blog post fails to engage the reader. Th...
# 4    *  The blog is informative but could be more e...
# 5    * While the subject matter is inherently inter...
# 6    * The blog engages the reader to a degree, usi...
# ..                                                 ...
# 97   * The blog lacks engaging elements.  While the...
# 98   * The blog is informative but lacks elements t...
# 99   * The blog post lacks compelling storytelling ...
# 100  * The blog lacks engaging elements.  There are...
# 101  * The repetitive nature of the text actively d...
#
#                                   Conciseness Comments
# 2    * The blog is somewhat verbose. Many sentences...
# 3    * This is the most significant weakness. The b...
# 4    * The blog could be more concise.  Some sectio...
# 5    *  The blog is somewhat verbose.  Some points ...
# 6    * The blog is significantly too long and repet...
# ..                                                 ...
# 97   *  The blog is significantly too verbose.  Muc...
# 98   *  The blog could be more concise.  Some point...
# 99   *  Several sections could be made more concise...
# 100  * This is another severely deficient area. The...
# 101  * This is the blog's biggest weakness.  The va...
#
# [100 rows x 16 columns]

# %%
df.drop(columns=['assessment_70b', 'Scores', 'Suggestions']).to_csv('70b_results.csv', index=False)

# %%
ndf = df[['id', 'Clarity', 'Grammar and Syntax', 'Tone Appropriateness', 'Sentence Structure and Flow', 'Engagement', 'Conciseness']]

# %%
ndf
# Out:
#               id  Clarity  Grammar and Syntax  Tone Appropriateness  \
# 0    TRdL6ZzWBS0        7                   8                     9
# 1    TPXTmVdlyoc        7                   8                     9
# 2    -t1_ffaFXao        7                   8                     9
# 3    BCdV6BMMpOo        7                   8                     9
# 6    Kedt2or9xlo        7                   8                     9
# ..           ...      ...                 ...                   ...
# 97   IHg6ixt3CKc        7                   8                     9
# 98   A22Ej6kb2wo        7                   8                     8
# 99   jdIyNMkusLE        7                   8                     7
# 100  WgytXF0SPh0        7                   8                     8
# 101  4oDZyOf6CW4        7                   8                     8
#
#      Sentence Structure and Flow  Engagement  Conciseness
# 0                              7           6          5.0
# 1                              7           6          6.0
# 2                              7           6          6.0
# 3                              7           6          6.0
# 6                              7           7          6.0
# ..                           ...         ...          ...
# 97                             7           6          5.0
# 98                             6           6          5.0
# 99                             6           6          5.0
# 100                            6           6          5.0
# 101                            6           7          5.0
#
# [100 rows x 7 columns]

# %%
ndf = df[['id', 'Clarity', 'Grammar and Syntax', 'Tone Appropriateness', 'Sentence Structure and Flow', 'Engagement', 'Conciseness']]
ndf.columns[1:]
# Out:
# Index(['Clarity', 'Grammar and Syntax', 'Tone Appropriateness',
#        'Sentence Structure and Flow', 'Engagement', 'Conciseness'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create violin plots for each attribute
plt.figure(figsize=(12, 7))
ax = sns.violinplot(data=ndf[attributes])
plt.title('Violin Plot for Metrics on the LLama 70B Blogs', fontsize=12, fontweight='bold')
plt.xlabel('Metrics from LLM Judge (Gemini Flash)', fontsize=14, fontweight='bold')
plt.ylabel('Scores', fontsize=14, fontweight='bold')
# Customize x-axis ticks and labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right', fontsize=12)
plt.xticks(ticks=range(len(attributes)), labels=attributes, fontsize=8, fontweight='bold')

plt.show()
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_65851/3735897101.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right', fontsize=12)

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Heatmap for correlation matrix
plt.figure(figsize=(10, 8))
correlation_matrix = ndf[attributes].corr()

# Heatmap for correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, xticklabels=attributes, yticklabels=attributes, annot_kws={"fontweight": "bold"})
plt.title('Heatmap of Attribute Correlations for LLama 70B', fontweight='bold', fontsize=14)
plt.show()

# %%
ndf.isna().sum()
# Out:
# id                             0
# Clarity                        0
# Grammar and Syntax             0
# Tone Appropriateness           0
# Sentence Structure and Flow    0
# Engagement                     0
# Conciseness                    0
# dtype: int64

# %%
# replace na with 0 
ndf.fillna(0, inplace=True)
# Out:
# /var/folders/r_/3zpp4z8x0jsdx29mzsxh1c_80000gn/T/ipykernel_63829/1925477976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf.fillna(0, inplace=True)
